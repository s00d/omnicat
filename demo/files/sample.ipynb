# %% [markdown]
# # Notebook cell 1
#
# Markdown **demo** for omnicat slides preview.

# %%
print('code cell — shown as raw in notebook driver fallback')

# %% [markdown]
# ## Cell 3
#
# Another markdown slide.
